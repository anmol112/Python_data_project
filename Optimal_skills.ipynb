# %%
import pandas as pd
import matplotlib.pyplot as plt
import datetime as dt
from datasets import load_dataset
import ast
import matplotlib.ticker as ticker
import seaborn as sns
from adjustText import adjust_text

# %%
ds_copy = pd.read_csv('datasets/ds_cleaned_csv')
#CSV DATASET

# %%
ds_copy['job_posted_date'] = pd.to_datetime(ds_copy['job_posted_date'])

# %% [markdown]
# nexxt step because we imported from csv so all data types changed into string

# %%
ds_copy['job_skills_copy'] = ds_copy['job_skills_copy'].apply(ast.literal_eval)

# %%
ds_copy['job_type_skills_copy'] = ds_copy['job_type_skills_copy'].apply(ast.literal_eval)

# %%
ds_copy.to_pickle('datasets/ds_cleaned_2')

# %%
jobs_per_category = ds_copy.groupby('job_title_short')['job_title'].count().sort_values(ascending=False)

# %%
count_per_salary = ds_copy.groupby('job_title_short').agg(
    jobs_posting = ('job_title_short' , 'count'),
    avg_salary = ('salary_year_avg','median')
)

# %%
count_per_salary.plot(kind='scatter' , x = 'jobs_posting' , y = 'avg_salary') 



#plt.text(x , y , text)
for i , text in enumerate(count_per_salary.index):
    plt.text(count_per_salary['jobs_posting'][i] , count_per_salary['avg_salary'][i] , text )
# Out:
# C:\Users\anmol\AppData\Local\Temp\ipykernel_5872\34196812.py:7: FutureWarning: Series.__getitem__ treating keys as positions is deprecated. In a future version, integer keys will always be treated as labels (consistent with DataFrame behavior). To access a value by position, use `ser.iloc[pos]`
#   plt.text(count_per_salary['jobs_posting'][i] , count_per_salary['avg_salary'][i] , text )

# %%
count_per_salary
# Out:
#                            jobs_posting  avg_salary
# job_title_short
# Business Analyst                  49053     85000.0
# Cloud Engineer                    12331     90000.0
# Data Analyst                     196050     90000.0
# Data Engineer                    186216    125000.0
# Data Scientist                   172263    127500.0
# Machine Learning Engineer         14079    106415.0
# Senior Data Analyst               29214    111175.0
# Senior Data Engineer              44561    147500.0
# Senior Data Scientist             36955    155500.0
# Software Engineer                 44918     99150.0

# %%
top_3 = ds_copy.groupby('job_title_short')['job_title_short'].count().sort_values(ascending=False).head(3)

# %%
ds_copy_2 = ds_copy.copy()

# %%
ds_copy
# Out:
#              job_title_short  \
# 0       Senior Data Engineer
# 1               Data Analyst
# 2              Data Engineer
# 3              Data Engineer
# 4              Data Engineer
# ...                      ...
# 785635     Software Engineer
# 785636          Data Analyst
# 785637      Business Analyst
# 785638         Data Engineer
# 785639     Software Engineer
#
#                                                 job_title  \
# 0       Senior Clinical Data Engineer / Principal Clin...
# 1                                            Data Analyst
# 2       Data Engineer/Scientist/Analyst, Mid or Senior...
# 3       LEAD ENGINEER - PRINCIPAL ANALYST - PRINCIPAL ...
# 4                                  Data Engineer- Sr Jobs
# ...                                                   ...
# 785635                                    DevOps Engineer
# 785636                                   CRM Data Analyst
# 785637                     Commercial Analyst - Start Now
# 785638  Principal Associate, Data Engineer (Remote-Eli...
# 785639                                 AWS System Analyst
#
#                                job_location                    job_via  \
# 0                             Watertown, CT            via Work Nearby
# 1              Guadalajara, Jalisco, Mexico           via BeBee México
# 2                           Berlin, Germany               via LinkedIn
# 3                           San Antonio, TX          via Diversity.com
# 4                            Washington, DC         via Clearance Jobs
# ...                                     ...                        ...
# 785635                            Singapura        melalui Trabajo.org
# 785636                   Bad Rodach, Jerman  melalui BeBee Deutschland
# 785637                             Malaysia           melalui Ricebowl
# 785638  Newark, New Jersey, Amerika Serikat        melalui Recruit.net
# 785639                                India             melalui Trigyn
#
#        job_schedule_type  job_work_from_home       search_location  \
# 0              Full-time               False  Texas, United States
# 1              Full-time               False                Mexico
# 2              Full-time               False               Germany
# 3              Full-time               False  Texas, United States
# 4              Full-time               False                 Sudan
# ...                  ...                 ...                   ...
# 785635   Pekerjaan tetap               False             Singapore
# 785636   Pekerjaan tetap               False               Germany
# 785637   Pekerjaan tetap               False              Malaysia
# 785638   Pekerjaan tetap               False                 Sudan
# 785639   Pekerjaan tetap               False                 India
#
#            job_posted_date  job_no_degree_mention  job_health_insurance  \
# 0      2023-06-16 13:44:15                  False                 False
# 1      2023-01-14 13:18:07                  False                 False
# 2      2023-10-10 13:14:55                  False                 False
# 3      2023-07-04 13:01:41                   True                 False
# 4      2023-08-07 14:29:36                  False                 False
# ...                    ...                    ...                   ...
# 785635 2023-03-13 06:16:16                  False                 False
# 785636 2023-03-12 06:18:18                  False                 False
# 785637 2023-03-12 06:32:36                  False                 False
# 785638 2023-03-12 06:32:15                  False                 False
# 785639 2023-03-13 06:16:31                  False                 False
#
#           job_country salary_rate  salary_year_avg  salary_hour_avg  \
# 0       United States         NaN              NaN              NaN
# 1              Mexico         NaN              NaN              NaN
# 2             Germany         NaN              NaN              NaN
# 3       United States         NaN              NaN              NaN
# 4               Sudan         NaN              NaN              NaN
# ...               ...         ...              ...              ...
# 785635      Singapore         NaN              NaN              NaN
# 785636        Germany         NaN              NaN              NaN
# 785637       Malaysia         NaN              NaN              NaN
# 785638          Sudan         NaN              NaN              NaN
# 785639          India         NaN              NaN              NaN
#
#                               company_name  \
# 0                     Boehringer Ingelheim
# 1               Hewlett Packard Enterprise
# 2                 ALPHA Augmented Services
# 3             Southwest Research Institute
# 4                          Kristina Daniel
# ...                                    ...
# 785635  CAREERSTAR INTERNATIONAL PTE. LTD.
# 785636                    HABA FAMILYGROUP
# 785637               Lendlease Corporation
# 785638                         Capital One
# 785639                              Trigyn
#
#                                           job_skills_copy  \
# 0                                                      []
# 1              [r, python, sql, nosql, power bi, tableau]
# 2       [python, sql, c#, azure, airflow, dax, docker,...
# 3       [python, c++, java, matlab, aws, tensorflow, k...
# 4       [bash, python, oracle, aws, ansible, puppet, j...
# ...                                                   ...
# 785635  [bash, python, perl, linux, unix, kubernetes, ...
# 785636                             [sas, sas, sql, excel]
# 785637                                [powerpoint, excel]
# 785638  [python, go, nosql, sql, mongo, shell, mysql, ...
# 785639                                        [aws, flow]
#
#                                      job_type_skills_copy
# 0                                                      {}
# 1       {'analyst_tools': ['power bi', 'tableau'], 'pr...
# 2       {'analyst_tools': ['dax'], 'cloud': ['azure'],...
# 3       {'cloud': ['aws'], 'libraries': ['tensorflow',...
# 4       {'cloud': ['oracle', 'aws'], 'other': ['ansibl...
# ...                                                   ...
# 785635  {'os': ['linux', 'unix'], 'other': ['kubernete...
# 785636  {'analyst_tools': ['sas', 'excel'], 'programmi...
# 785637         {'analyst_tools': ['powerpoint', 'excel']}
# 785638  {'cloud': ['aws', 'snowflake', 'azure', 'redsh...
# 785639              {'cloud': ['aws'], 'other': ['flow']}
#
# [785640 rows x 17 columns]

# %%
optimal_skills = ds_copy

# %%
optimal_skills
# Out:
#              job_title_short  \
# 0       Senior Data Engineer
# 1               Data Analyst
# 2              Data Engineer
# 3              Data Engineer
# 4              Data Engineer
# ...                      ...
# 785635     Software Engineer
# 785636          Data Analyst
# 785637      Business Analyst
# 785638         Data Engineer
# 785639     Software Engineer
#
#                                                 job_title  \
# 0       Senior Clinical Data Engineer / Principal Clin...
# 1                                            Data Analyst
# 2       Data Engineer/Scientist/Analyst, Mid or Senior...
# 3       LEAD ENGINEER - PRINCIPAL ANALYST - PRINCIPAL ...
# 4                                  Data Engineer- Sr Jobs
# ...                                                   ...
# 785635                                    DevOps Engineer
# 785636                                   CRM Data Analyst
# 785637                     Commercial Analyst - Start Now
# 785638  Principal Associate, Data Engineer (Remote-Eli...
# 785639                                 AWS System Analyst
#
#                                job_location                    job_via  \
# 0                             Watertown, CT            via Work Nearby
# 1              Guadalajara, Jalisco, Mexico           via BeBee México
# 2                           Berlin, Germany               via LinkedIn
# 3                           San Antonio, TX          via Diversity.com
# 4                            Washington, DC         via Clearance Jobs
# ...                                     ...                        ...
# 785635                            Singapura        melalui Trabajo.org
# 785636                   Bad Rodach, Jerman  melalui BeBee Deutschland
# 785637                             Malaysia           melalui Ricebowl
# 785638  Newark, New Jersey, Amerika Serikat        melalui Recruit.net
# 785639                                India             melalui Trigyn
#
#        job_schedule_type  job_work_from_home       search_location  \
# 0              Full-time               False  Texas, United States
# 1              Full-time               False                Mexico
# 2              Full-time               False               Germany
# 3              Full-time               False  Texas, United States
# 4              Full-time               False                 Sudan
# ...                  ...                 ...                   ...
# 785635   Pekerjaan tetap               False             Singapore
# 785636   Pekerjaan tetap               False               Germany
# 785637   Pekerjaan tetap               False              Malaysia
# 785638   Pekerjaan tetap               False                 Sudan
# 785639   Pekerjaan tetap               False                 India
#
#            job_posted_date  job_no_degree_mention  job_health_insurance  \
# 0      2023-06-16 13:44:15                  False                 False
# 1      2023-01-14 13:18:07                  False                 False
# 2      2023-10-10 13:14:55                  False                 False
# 3      2023-07-04 13:01:41                   True                 False
# 4      2023-08-07 14:29:36                  False                 False
# ...                    ...                    ...                   ...
# 785635 2023-03-13 06:16:16                  False                 False
# 785636 2023-03-12 06:18:18                  False                 False
# 785637 2023-03-12 06:32:36                  False                 False
# 785638 2023-03-12 06:32:15                  False                 False
# 785639 2023-03-13 06:16:31                  False                 False
#
#           job_country salary_rate  salary_year_avg  salary_hour_avg  \
# 0       United States         NaN              NaN              NaN
# 1              Mexico         NaN              NaN              NaN
# 2             Germany         NaN              NaN              NaN
# 3       United States         NaN              NaN              NaN
# 4               Sudan         NaN              NaN              NaN
# ...               ...         ...              ...              ...
# 785635      Singapore         NaN              NaN              NaN
# 785636        Germany         NaN              NaN              NaN
# 785637       Malaysia         NaN              NaN              NaN
# 785638          Sudan         NaN              NaN              NaN
# 785639          India         NaN              NaN              NaN
#
#                               company_name  \
# 0                     Boehringer Ingelheim
# 1               Hewlett Packard Enterprise
# 2                 ALPHA Augmented Services
# 3             Southwest Research Institute
# 4                          Kristina Daniel
# ...                                    ...
# 785635  CAREERSTAR INTERNATIONAL PTE. LTD.
# 785636                    HABA FAMILYGROUP
# 785637               Lendlease Corporation
# 785638                         Capital One
# 785639                              Trigyn
#
#                                           job_skills_copy  \
# 0                                                      []
# 1              [r, python, sql, nosql, power bi, tableau]
# 2       [python, sql, c#, azure, airflow, dax, docker,...
# 3       [python, c++, java, matlab, aws, tensorflow, k...
# 4       [bash, python, oracle, aws, ansible, puppet, j...
# ...                                                   ...
# 785635  [bash, python, perl, linux, unix, kubernetes, ...
# 785636                             [sas, sas, sql, excel]
# 785637                                [powerpoint, excel]
# 785638  [python, go, nosql, sql, mongo, shell, mysql, ...
# 785639                                        [aws, flow]
#
#                                      job_type_skills_copy
# 0                                                      {}
# 1       {'analyst_tools': ['power bi', 'tableau'], 'pr...
# 2       {'analyst_tools': ['dax'], 'cloud': ['azure'],...
# 3       {'cloud': ['aws'], 'libraries': ['tensorflow',...
# 4       {'cloud': ['oracle', 'aws'], 'other': ['ansibl...
# ...                                                   ...
# 785635  {'os': ['linux', 'unix'], 'other': ['kubernete...
# 785636  {'analyst_tools': ['sas', 'excel'], 'programmi...
# 785637         {'analyst_tools': ['powerpoint', 'excel']}
# 785638  {'cloud': ['aws', 'snowflake', 'azure', 'redsh...
# 785639              {'cloud': ['aws'], 'other': ['flow']}
#
# [785640 rows x 17 columns]

# %%
optimal_skills = optimal_skills[optimal_skills['salary_year_avg'].notna()]

# %%
total_jobs = optimal_skills['job_title_short'].count()

# %%
total_jobs
# Out:
# 22002

# %%
optimal_skills = optimal_skills.explode('job_skills_copy')

# %%
optimal_skills = optimal_skills.drop('job_type_skills_copy' , axis=1)

# %%
optimal_skills.drop_duplicates(inplace=True)

# %%
optimal_skills
# Out:
#        job_title_short                                          job_title  \
# 28      Data Scientist                                CRM Data Specialist
# 28      Data Scientist                                CRM Data Specialist
# 77       Data Engineer                                      Data Engineer
# 77       Data Engineer                                      Data Engineer
# 77       Data Engineer                                      Data Engineer
# ...                ...                                                ...
# 785581  Data Scientist  Data Scientist für datengetriebene Entwicklung...
# 785581  Data Scientist  Data Scientist für datengetriebene Entwicklung...
# 785591  Data Scientist               Data Scientist- Hybrid Work Location
# 785591  Data Scientist               Data Scientist- Hybrid Work Location
# 785591  Data Scientist               Data Scientist- Hybrid Work Location
#
#                                    job_location          job_via  \
# 28      San José Province, San José, Costa Rica  via Ai-Jobs.net
# 28      San José Province, San José, Costa Rica  via Ai-Jobs.net
# 77                                Arlington, VA     via LinkedIn
# 77                                Arlington, VA     via LinkedIn
# 77                                Arlington, VA     via LinkedIn
# ...                                         ...              ...
# 785581                      Reutlingen, Germany  via Ai-Jobs.net
# 785581                      Reutlingen, Germany  via Ai-Jobs.net
# 785591                               Dayton, OH  via Ai-Jobs.net
# 785591                               Dayton, OH  via Ai-Jobs.net
# 785591                               Dayton, OH  via Ai-Jobs.net
#
#        job_schedule_type  job_work_from_home          search_location  \
# 28             Full-time               False               Costa Rica
# 28             Full-time               False               Costa Rica
# 77             Full-time               False                    Sudan
# 77             Full-time               False                    Sudan
# 77             Full-time               False                    Sudan
# ...                  ...                 ...                      ...
# 785581         Full-time               False                  Germany
# 785581         Full-time               False                  Germany
# 785591         Full-time               False  Illinois, United States
# 785591         Full-time               False  Illinois, United States
# 785591         Full-time               False  Illinois, United States
#
#            job_posted_date  job_no_degree_mention  job_health_insurance  \
# 28     2023-08-01 13:37:57                  False                 False
# 28     2023-08-01 13:37:57                  False                 False
# 77     2023-06-26 14:22:54                  False                 False
# 77     2023-06-26 14:22:54                  False                 False
# 77     2023-06-26 14:22:54                  False                 False
# ...                    ...                    ...                   ...
# 785581 2023-03-04 06:16:08                  False                 False
# 785581 2023-03-04 06:16:08                  False                 False
# 785591 2023-04-21 06:02:31                  False                  True
# 785591 2023-04-21 06:02:31                  False                  True
# 785591 2023-04-21 06:02:31                  False                  True
#
#           job_country salary_rate  salary_year_avg  salary_hour_avg  \
# 28         Costa Rica        year         109500.0              NaN
# 28         Costa Rica        year         109500.0              NaN
# 77              Sudan        year         140000.0              NaN
# 77              Sudan        year         140000.0              NaN
# 77              Sudan        year         140000.0              NaN
# ...               ...         ...              ...              ...
# 785581        Germany        year         157500.0              NaN
# 785581        Germany        year         157500.0              NaN
# 785591  United States        year         157500.0              NaN
# 785591  United States        year         157500.0              NaN
# 785591  United States        year         157500.0              NaN
#
#        company_name job_skills_copy
# 28         Netskope            gdpr
# 28         Netskope           excel
# 77       Intelletec         mongodb
# 77       Intelletec          python
# 77       Intelletec               r
# ...             ...             ...
# 785581  Bosch Group         airflow
# 785581  Bosch Group      kubernetes
# 785591       Tenet3          python
# 785591       Tenet3          matlab
# 785591       Tenet3               r
#
# [118501 rows x 16 columns]

# %%
optimal_skills_2 = optimal_skills.groupby('job_skills_copy').agg(
    count = ('job_skills_copy' , 'count'),
    salary = ('salary_year_avg' , 'median')
)

# %%
optimal_skills_2.reset_index(inplace=True)

# %%
k = ds_copy['job_type_skills_copy']

# %%
k_list = k.to_list()

# %%
k_list[20]
# Out:
# {'libraries': ['pandas',
#   'numpy',
#   'scikit-learn',
#   'matplotlib',
#   'hadoop',
#   'spark'],
#  'programming': ['r', 'python', 'sql']}

# %% [markdown]
# make a function for dict to combine dicts

# %%
#code that join items of all dict into one unique dict
final_list = {}

for one in k_list:
    # can make dict combined one to final 
    for k in one :
        if k in final_list.keys():
            #keyname == val
            #checking if key belongs in final keys

            for value in one[k]:

                if value in final_list[k]:
                    pass
                    #because same value h final m 

                else :
                    #update krde value nhi h is final[keys] me 
                    final_list[k].append(value)

        else:
            #update krde direct key value pair 

            final_list[k] = one[k]

# %%
final_list
# Out:
# {'analyst_tools': ['power bi',
#   'tableau',
#   'dax',
#   'excel',
#   'powerpoint',
#   'qlik',
#   'sap',
#   'looker',
#   'word',
#   'sas',
#   'spss',
#   'microstrategy',
#   'cognos',
#   'outlook',
#   'splunk',
#   'alteryx',
#   'ssis',
#   'sharepoint',
#   'ms access',
#   'visio',
#   'datarobot',
#   'ssrs',
#   'spreadsheet',
#   'sheets',
#   'powerbi',
#   'nuix',
#   'msaccess',
#   'esquisse'],
#  'programming': ['r',
#   'python',
#   'sql',
#   'nosql',
#   'c#',
#   'c++',
#   'java',
#   'matlab',
#   'bash',
#   'mongodb',
#   'php',
#   'go',
#   'ruby',
#   'javascript',
#   'powershell',
#   'apl',
#   'scala',
#   'mongo',
#   'shell',
#   'sas',
#   'vba',
#   'c',
#   'html',
#   'css',
#   'lua',
#   'perl',
#   'golang',
#   't-sql',
#   'typescript',
#   'sass',
#   'visual basic',
#   'solidity',
#   'swift',
#   'kotlin',
#   'julia',
#   'fortran',
#   'no-sql',
#   'groovy',
#   'crystal',
#   'rust',
#   'assembly',
#   'dart',
#   'f#',
#   'cobol',
#   'objective-c',
#   'vb.net',
#   'elixir',
#   'pascal',
#   'lisp',
#   'clojure',
#   'delphi',
#   'erlang',
#   'haskell',
#   'ocaml',
#   'visualbasic'],
#  'cloud': ['azure',
#   'aws',
#   'oracle',
#   'gcp',
#   'bigquery',
#   'databricks',
#   'redshift',
#   'snowflake',
#   'aurora',
#   'firebase',
#   'ibm cloud',
#   'vmware',
#   'openstack',
#   'digitalocean',
#   'watson',
#   'heroku',
#   'linode',
#   'colocation',
#   'ovh'],
#  'libraries': ['airflow',
#   'tensorflow',
#   'keras',
#   'pytorch',
#   'hadoop',
#   'kafka',
#   'spark',
#   'pandas',
#   'numpy',
#   'scikit-learn',
#   'matplotlib',
#   'gdpr',
#   'pyspark',
#   'nltk',
#   'selenium',
#   'graphql',
#   'react',
#   'jupyter',
#   'spring',
#   'ionic',
#   'electron',
#   'tidyverse',
#   'opencv',
#   'rshiny',
#   'plotly',
#   'seaborn',
#   'ggplot2',
#   'mxnet',
#   'hugging face',
#   'theano',
#   'flutter',
#   'dplyr',
#   'mlr',
#   'xamarin',
#   'cordova',
#   'dlib',
#   'chainer',
#   'qt',
#   'tidyr',
#   'mlpack',
#   'capacitor',
#   'shogun',
#   'huggingface',
#   'gtx'],
#  'other': ['docker',
#   'kubernetes',
#   'jenkins',
#   'ansible',
#   'puppet',
#   'gitlab',
#   'git',
#   'terraform',
#   'flow',
#   'chef',
#   'github',
#   'unity',
#   'npm',
#   'bitbucket',
#   'terminal',
#   'yarn',
#   'atlassian',
#   'codecommit',
#   'pulumi',
#   'svn',
#   'unreal',
#   'homebrew'],
#  'databases': ['sql server',
#   'mongodb',
#   'mysql',
#   'elasticsearch',
#   'cassandra',
#   'neo4j',
#   'postgresql',
#   'dynamodb',
#   'mariadb',
#   'redis',
#   'firebase',
#   'couchbase',
#   'db2',
#   'sqlite',
#   'firestore',
#   'couchdb',
#   'sqlserver'],
#  'os': ['windows',
#   'linux',
#   'unix',
#   'redhat',
#   'arch',
#   'ubuntu',
#   'debian',
#   'macos',
#   'centos',
#   'fedora',
#   'wsl',
#   'kali',
#   'suse'],
#  'async': ['jira',
#   'confluence',
#   'smartsheet',
#   'notion',
#   'asana',
#   'planner',
#   'airtable',
#   'trello',
#   'wrike',
#   'workfront',
#   'monday.com',
#   'dingtalk',
#   'clickup',
#   'microsoft lists',
#   'wimi'],
#  'webframeworks': ['ruby',
#   'flask',
#   'fastapi',
#   'angular',
#   'vue',
#   'express',
#   'jquery',
#   'django',
#   'phoenix',
#   'symfony',
#   'node',
#   'node.js',
#   'asp.net',
#   'laravel',
#   'svelte',
#   'react.js',
#   'vue.js',
#   'ruby on rails',
#   'drupal',
#   'asp.net core',
#   'fastify',
#   'next.js',
#   'blazor',
#   'angular.js',
#   'gatsby',
#   'play framework',
#   'nuxt.js',
#   'ember.js',
#   'rubyon rails',
#   'asp.netcore',
#   'deno'],
#  'sync': ['zoom',
#   'slack',
#   'unify',
#   'microsoft teams',
#   'ringcentral',
#   'symphony',
#   'twilio',
#   'webex',
#   'wire',
#   'mattermost',
#   'google chat',
#   'rocketchat']}

# %%
#-----------------------------------
#convert dict into desired dataframe 
data = [(key, value) for key, values in final_list.items() for value in values]

# Convert the list of tuples into a DataFrame
skill_types = pd.DataFrame(data, columns=["Key", "Value"])

# %%
skill_types.drop_duplicates(inplace=True)

# %%
optimal_skills_2.drop_duplicates(inplace=True)

# %%
optimal_skills_2.sort_values(by='count' , ascending=False)
# Out:
#     job_skills_copy  count    salary
# 177             sql  12949  120000.0
# 143          python  12868  125000.0
# 147               r   5087  119550.0
# 14              aws   4949  135000.0
# 188         tableau   4812  111175.0
# ..              ...    ...       ...
# 44           debian      1  196500.0
# 59          fastify      1  133000.0
# 45           delphi      1   98496.0
# 146              qt      1  110000.0
# 130          pascal      1   92000.0
#
# [219 rows x 3 columns]

# %%
skill_types
# Out:
#                Key        Value
# 0    analyst_tools     power bi
# 1    analyst_tools      tableau
# 2    analyst_tools          dax
# 3    analyst_tools        excel
# 4    analyst_tools   powerpoint
# ..             ...          ...
# 251           sync        webex
# 252           sync         wire
# 253           sync   mattermost
# 254           sync  google chat
# 255           sync   rocketchat
#
# [256 rows x 2 columns]

# %%
optimal_skills_final = pd.merge(optimal_skills_2 , skill_types , left_on='job_skills_copy',right_on='Value')

# %%
optimal_skills_final['count'] = optimal_skills_final['count'] * 100/total_jobs

# %%
optimal_skills_final_2 = optimal_skills_final.sort_values(by='count', ascending=False).head(15)

# %%
optimal_skills_final_2.to_pickle('data_graphs/optimal_skills')

# %%
plt.figure(figsize=(10,7))
sns.scatterplot(optimal_skills_final_2 , x='count', y='salary' , hue='Key')
plt.xlabel('probability for expecting in job posting')
plt.ylabel('Average Salary')

texts = []
for i ,text in enumerate(optimal_skills_final_2['job_skills_copy']):
    texts.append(plt.text(optimal_skills_final_2['count'].iloc[i] , optimal_skills_final_2['salary'].iloc[i] , text))

adjust_text(texts , arrowprops=dict(arrowstyle="->" , color='black' , lw=1))

ax = plt.gca()
ax.xaxis.set_major_formatter(ticker.FuncFormatter(lambda x , pos:f'{x}%'))
ax.yaxis.set_major_formatter(ticker.FuncFormatter(lambda y , pos:f'{int(y/1000)}K'))
sns.despine()
plt.legend(title = None)
