# %%
import pandas as pd
from datasets import load_dataset

dataset = load_dataset("lukebarousse/data_jobs")

# %%
import datetime as dt

# %%
ds = dataset['train'].to_pandas()

# %%
ds['job_post_date'] = pd.to_datetime(ds['job_posted_date'])
ds.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 785741 entries, 0 to 785740
# Data columns (total 18 columns):
#  #   Column                 Non-Null Count   Dtype
# ---  ------                 --------------   -----
#  0   job_title_short        785741 non-null  object
#  1   job_title              785740 non-null  object
#  2   job_location           784696 non-null  object
#  3   job_via                785733 non-null  object
#  4   job_schedule_type      773074 non-null  object
#  5   job_work_from_home     785741 non-null  bool
#  6   search_location        785741 non-null  object
#  7   job_posted_date        785741 non-null  object
#  8   job_no_degree_mention  785741 non-null  bool
#  9   job_health_insurance   785741 non-null  bool
#  10  job_country            785692 non-null  object
#  11  salary_rate            33067 non-null   object
#  12  salary_year_avg        22003 non-null   float64
#  13  salary_hour_avg        10662 non-null   float64
# ...

# %%
columns_name = (list(ds.columns))
columns_name
column_name = [] 
for val in columns_name:
    if val != 'job_posted_date':
        column_name.append(val)

ds = ds.drop_duplicates()

# %%
ds['job_skills'][1]
# Out:
# "['r', 'python', 'sql', 'nosql', 'power bi', 'tableau']"

# %%
def lstr_list(string):
    line = ""
    final_list = []
    switch = 'off'

    if string is None or string == "" :
        return []

    else:
        for val in string:
            if val == "'" and switch == 'off':
                switch = 'on'  # Corrected assignment operator

            elif val == "'" and switch == 'on':
                switch = 'off'
                final_list.append(line)
                line = ""

            elif val != "'" and switch == 'on':
                line += val  # Corrected to concatenate characters



    return final_list

# %%
ds_copy = ds.copy()

# %%
ds_copy['job_skills'] = ds_copy['job_skills'].apply(lstr_list , 0)
ds_copy['job_skills']
# Out:
# C:\Users\anmol\AppData\Local\Temp\ipykernel_21552\3650323528.py:1: FutureWarning: the convert_dtype parameter is deprecated and will be removed in a future version.  Do ``ser.astype(object).apply()`` instead if you want ``convert_dtype=False``.
#   ds_copy['job_skills'] = ds_copy['job_skills'].apply(lstr_list , 0)
# 0                                                        []
# 1                [r, python, sql, nosql, power bi, tableau]
# 2         [python, sql, c#, azure, airflow, dax, docker,...
# 3         [python, c++, java, matlab, aws, tensorflow, k...
# 4         [bash, python, oracle, aws, ansible, puppet, j...
#                                 ...
# 785736    [bash, python, perl, linux, unix, kubernetes, ...
# 785737                               [sas, sas, sql, excel]
# 785738                                  [powerpoint, excel]
# 785739    [python, go, nosql, sql, mongo, shell, mysql, ...
# 785740                                          [aws, flow]
# ...

# %%
ds_copy = ds.copy()
ds_copy
# Out:
#              job_title_short  \
# 0       Senior Data Engineer
# 1               Data Analyst
# 2              Data Engineer
# 3              Data Engineer
# 4              Data Engineer
# ...                      ...
# 785736     Software Engineer
# 785737          Data Analyst
# 785738      Business Analyst
# 785739         Data Engineer
# 785740     Software Engineer
#
#                                                 job_title  \
# 0       Senior Clinical Data Engineer / Principal Clin...
# 1                                            Data Analyst
# 2       Data Engineer/Scientist/Analyst, Mid or Senior...
# 3       LEAD ENGINEER - PRINCIPAL ANALYST - PRINCIPAL ...
# 4                                  Data Engineer- Sr Jobs
# ...                                                   ...
# 785736                                    DevOps Engineer
# 785737                                   CRM Data Analyst
# 785738                     Commercial Analyst - Start Now
# ...

# %%
# Function to split strings based on single quotes
def lstr_list(string):
    if string is None:
        return []  # Return an empty list if the input is None
    
    line = ""
    final_list = []
    switch = 'off'

    for val in string:
        if val == "'" and switch == 'off':
            switch = 'on'
        elif val == "'" and switch == 'on':
            switch = 'off'
            if line:
                final_list.append(line)
                line = ""
        elif val != "'" and switch == 'on':
            line += val

    if line:
        final_list.append(line)

    return final_list

# Apply function to each cell in the 'col' column
ds_copy['job_skills_copy'] = ds_copy['job_skills'].apply(lstr_list)
type(ds_copy['job_skills_copy'][1])
# Out:
# list

# %%
ds_copy['job_type_skills'][1]
# Out:
# "{'analyst_tools': ['power bi', 'tableau'], 'programming': ['r', 'python', 'sql', 'nosql']}"

# %%
import ast 

def str_dict(string):

    if pd.isna(string) or string == "":
        return {}
    
    else :
        return ast.literal_eval(string)
    




ds_copy['job_type_skills_copy'] = ds_copy['job_type_skills'].apply(str_dict)

# %%
type(ds_copy['job_type_skills_copy'][1])
# Out:
# dict

# %%
ds_copy = ds_copy.drop(['job_skills' , 'job_type_skills'] , axis = 1)

# %%
ds_copy = ds_copy.drop(['job_post_date'] , axis=1)

# %%
data_analyst_ =  ds_copy[ds_copy['job_title_short' ] == 'Data Analyst']

# %%
ds_copy['job_posted_date'] = pd.to_datetime(ds_copy['job_posted_date'])

# %%
ds_copy.to_csv('datasets/ds_cleaned_csv' , index= False)

# %%
ds_copy
# Out:
#              job_title_short  \
# 0       Senior Data Engineer
# 1               Data Analyst
# 2              Data Engineer
# 3              Data Engineer
# 4              Data Engineer
# ...                      ...
# 785736     Software Engineer
# 785737          Data Analyst
# 785738      Business Analyst
# 785739         Data Engineer
# 785740     Software Engineer
#
#                                                 job_title  \
# 0       Senior Clinical Data Engineer / Principal Clin...
# 1                                            Data Analyst
# 2       Data Engineer/Scientist/Analyst, Mid or Senior...
# 3       LEAD ENGINEER - PRINCIPAL ANALYST - PRINCIPAL ...
# 4                                  Data Engineer- Sr Jobs
# ...                                                   ...
# 785736                                    DevOps Engineer
# 785737                                   CRM Data Analyst
# 785738                     Commercial Analyst - Start Now
# ...

# %%
ds_copy[ds_copy['salary_year_avg'].notna()]
# Out:
#        job_title_short                                          job_title  \
# 28      Data Scientist                                CRM Data Specialist
# 77       Data Engineer                                      Data Engineer
# 92       Data Engineer            Remote - Data Engineer - Permanent - W2
# 100     Data Scientist            Data Scientist, Risk Data Mining - USDS
# 109       Data Analyst              Senior Supply Chain Analytics Analyst
# ...                ...                                                ...
# 785624   Data Engineer                   Data Analytics Engineer (Hybrid)
# 785641   Data Engineer                                      Data Engineer
# 785648  Data Scientist  Director Data Scientist - Commercial Platforms...
# 785682  Data Scientist  Data Scientist für datengetriebene Entwicklung...
# 785692  Data Scientist               Data Scientist- Hybrid Work Location
#
#                                    job_location          job_via  \
# ...
